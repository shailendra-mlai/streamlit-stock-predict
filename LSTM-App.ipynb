# %%
import numpy as np 
import pandas as pd 
from sklearn import preprocessing
import matplotlib.pyplot as plt 
import seaborn as sns
import warnings
warnings.simplefilter(action='ignore')
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.preprocessing import MinMaxScaler
import datetime 
import yfinance as yf
import tensorflow
from tensorflow import keras
from tensorflow.keras import Input
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import Huber
np.random.seed(42)
tensorflow.random.set_seed(42)

# %% [markdown]
# ### Lets use the functions to model new stock symbol from user input

# %%
# Inputting the Stock symbol for prediction
TICK = input("Enter Stock symbol for prediction : ")
# Out:
# Enter Stock symbol for prediction : META

# %% [markdown]
# ### Fetching Historical Data from yahoo finance API for the tickers

# %%
# Fetch the data for last 5 years from yahoo
ticker = yf.Ticker(TICK)
ticker_data = ticker.history(period="5y")
ticker_data['Company'] = TICK

# %%
ticker_data
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2019-05-20 00:00:00-04:00  181.687231  184.034731  181.177761  182.526337
# 2019-05-21 00:00:00-04:00  184.374380  185.503172  183.695093  184.624115
# 2019-05-22 00:00:00-04:00  184.534195  186.542074  183.415387  185.123581
# 2019-05-23 00:00:00-04:00  182.226659  183.705086  179.479574  180.678299
# 2019-05-24 00:00:00-04:00  182.136746  183.435371  180.638336  180.868088
# ...                               ...         ...         ...         ...
# 2024-05-14 00:00:00-04:00  463.369995  472.540009  460.079987  471.850006
# 2024-05-15 00:00:00-04:00  474.980011  482.500000  471.200012  481.540009
# 2024-05-16 00:00:00-04:00  475.000000  477.690002  472.750000  473.230011
# 2024-05-17 00:00:00-04:00  470.829987  472.799988  468.420013  471.910004
# 2024-05-20 00:00:00-04:00  469.950012  473.200012  467.040009  471.420013
#
#                              Volume  Dividends  Stock Splits Company
# Date
# 2019-05-20 00:00:00-04:00  10352000        0.0           0.0    META
# 2019-05-21 00:00:00-04:00   7502800        0.0           0.0    META
# 2019-05-22 00:00:00-04:00   9213800        0.0           0.0    META
# 2019-05-23 00:00:00-04:00  12768800        0.0           0.0    META
# 2019-05-24 00:00:00-04:00   8807700        0.0           0.0    META
# ...                             ...        ...           ...     ...
# 2024-05-14 00:00:00-04:00  10478600        0.0           0.0    META
# 2024-05-15 00:00:00-04:00  13100500        0.0           0.0    META
# 2024-05-16 00:00:00-04:00  16608200        0.0           0.0    META
# 2024-05-17 00:00:00-04:00   9979600        0.0           0.0    META
# 2024-05-20 00:00:00-04:00   5232910        0.0           0.0    META
#
# [1260 rows x 8 columns]

# %% [markdown]
# ### Visualize the stock portfolio performance of holding for last 5 years

# %%
# Visualize the stock portfolio performance of holding
fig, visual_plot = plt.subplots(figsize=(15,8))
visual_plot = sns.lineplot(data =ticker_data, x = ticker_data.index, y= ticker_data["Close"], hue = ticker_data["Company"])
visual_plot.set_title("Stock Prices of {}" .format(TICK))
visual_plot.set_xlabel('Last 5 Years', fontsize=16)
visual_plot.set_ylabel('Closing Price (USD)' , fontsize=16)
# Out:
# Text(0, 0.5, 'Closing Price (USD)')

# %% [markdown]
# ### Defining functions Model using LSTM calculate errors and predict stock price for next 30 days

# %%
# Define the function to retain only 'Close' prices
def close_prices_only(data):
    return data[['Close']]

# %%
## Function for scaling the data for LSTM

def min_max_scale(data):
    # Initialize MinMaxScaler
    scaler = MinMaxScaler(feature_range=(0, 1))
    
    # Fit and transform the data using the scaler
    scaled_data = scaler.fit_transform(data.values)
    
    return scaler, scaled_data

# %%
def split_and_reshape_data(dataframe, pred_days):
    # Define the number of days to predict
    prediction_days = pred_days
    
    # Calculate the sizes of the training and testing sets
    train_size = int(np.ceil(len(dataframe) * 0.95))
    test_size = len(dataframe) - train_size
    
    # Split the data into training and testing sets
    train_data = dataframe[0: int(train_size), :]
    test_data = dataframe[train_size - prediction_days:, :]
    
    # Initialize lists to store features and target values for training and testing
    X_train, y_train, X_test, y_test = [], [], [], []
    
    # Generate sequences of features and target values for training set
    for i in range(prediction_days, len(train_data)):
        X_train.append(train_data[i - prediction_days: i, 0])
        y_train.append(train_data[i, 0])
        
    # Generate sequences of features and target values for testing set
    for i in range(prediction_days, len(test_data)):
        X_test.append(test_data[i - prediction_days: i, 0])
        y_test.append(test_data[i, 0])
        
    # Convert lists to numpy arrays
    X_train, y_train, X_test, y_test = np.array(X_train), np.array(y_train), np.array(X_test), np.array(y_test)
    
    # Reshape the feature sets for LSTM input
    X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
    X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
    
    # Return the prepared data
    return X_train, y_train, X_test, y_test

# %%
def lstm_model(X_train, y_train, epochs=100, batch_size=32):
    """
    Function to build and train an LSTM model for stock price prediction.
    
    Parameters:
    - X_train: numpy array, training features
    - y_train: numpy array, training labels
    - epochs: int, number of epochs for training (default: 100)
    - batch_size: int, batch size for training (default: 32)
    
    Returns:
    - model: trained Keras model
    """
    # Build LSTM model
    model = Sequential()
    model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
    model.add(Dropout(0.2))
    model.add(LSTM(units=50, return_sequences=True))
    model.add(Dropout(0.2))
    model.add(LSTM(units=50, return_sequences=True))
    model.add(Dropout(0.2))
    model.add(LSTM(units=50))
    model.add(Dropout(0.2))
    model.add(Dense(units=1))

    # Compile the model
    model.compile(optimizer='adam', loss='mean_squared_error')

    # Train the model
    model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, verbose=0)

    return model

# %%
def predictions_inverse_scaler(scaler, model, X_test, y_test):
    """
    Function to inverse scale predicted and true values back to original scale.
    
    Parameters:
    - scaler: sklearn MinMaxScaler object, used for scaling the data
    - model: trained Keras model
    - X_test: numpy array, test features
    - y_test: numpy array, true test labels
    
    Returns:
    - y_pred: numpy array, inverse scaled predicted values
    - y_test: numpy array, inverse scaled true values
    """
    # Predictions using the model
    y_pred = model.predict(X_test)
    
    # Inverse scaling of predicted values
    y_pred = scaler.inverse_transform(y_pred)
    
    # Inverse scaling of true values
    y_test = scaler.inverse_transform(y_test.reshape(-1, 1))
    
    return y_pred, y_test

# %%
def plot_predictions(y_pred, y_true, ticker_label):
    """
    Function to plot predicted values against true values with ticker label.
    
    Parameters:
    - y_pred: numpy array, predicted values
    - y_true: numpy array, true values
    - ticker_label: str, label for the ticker
    """
    plt.figure(figsize=(10, 6))
    plt.plot(y_true, label='True Values')
    plt.plot(y_pred, label='Predicted Values')
    plt.title(f'True vs Predicted Values for {ticker_label}')
    plt.xlabel('Time')
    plt.ylabel('Price')
    plt.legend()
    plt.show()

# %%
df_close = close_prices_only(ticker_data)

# %%
# Scaling close prices for stock ticker
df_scaler, df_scaled = min_max_scale(df_close)

# %%
# Split and reshape data for each stock ticker
X_train, y_train, X_test, y_test = split_and_reshape_data(df_scaled, 30)

# %%
# Build the LSTM model
model_lstm = lstm_model(X_train, y_train)
# Out:
# 2024-05-20 09:32:16.424057: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-20 09:32:16.424755: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-20 09:32:16.425175: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-20 09:32:16.484773: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-20 09:32:16.485142: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-20 09:32:16.485467: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-20 09:32:16.542066: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-20 09:32:16.542486: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-20 09:32:16.542875: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-20 09:32:16.599957: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-20 09:32:16.600384: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-20 09:32:16.600807: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-20 09:32:16.629998: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2024-05-20 09:32:16.702882: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-20 09:32:16.703379: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-20 09:32:16.703817: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-20 09:32:16.767298: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-20 09:32:16.767804: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-20 09:32:16.768226: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-20 09:32:16.831970: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-20 09:32:16.832604: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-20 09:32:16.833086: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-20 09:32:16.900874: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-20 09:32:16.901391: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-20 09:32:16.901864: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-20 09:32:17.383182: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-20 09:32:17.383757: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-20 09:32:17.384176: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-20 09:32:17.445250: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-20 09:32:17.445752: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-20 09:32:17.446159: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-20 09:32:17.509837: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-20 09:32:17.510351: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-20 09:32:17.510804: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-20 09:32:17.575064: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-20 09:32:17.575520: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-20 09:32:17.575941: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
model_lstm.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 30, 50)            10400
#
#  dropout (Dropout)           (None, 30, 50)            0
#
#  lstm_1 (LSTM)               (None, 30, 50)            20200
#
#  dropout_1 (Dropout)         (None, 30, 50)            0
#
#  lstm_2 (LSTM)               (None, 30, 50)            20200
#
#  dropout_2 (Dropout)         (None, 30, 50)            0
#
#  lstm_3 (LSTM)               (None, 50)                20200
#
#  dropout_3 (Dropout)         (None, 50)                0
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 71,051
# Trainable params: 71,051
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Make predictions and inverse scale for each stock ticker
y_pred, y_test_inv = predictions_inverse_scaler(df_scaler, model_lstm, X_test, y_test)
# Out:
# 2024-05-20 09:33:19.062080: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-20 09:33:19.062602: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-20 09:33:19.063088: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-20 09:33:19.128236: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-20 09:33:19.128705: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-20 09:33:19.129139: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-20 09:33:19.194387: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-20 09:33:19.194844: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-20 09:33:19.195263: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-20 09:33:19.257724: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-20 09:33:19.258171: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-20 09:33:19.258591: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2/2 [==============================] - 0s 6ms/step

# %%
plot_predictions(y_pred, y_test_inv, TICK)

# %%
history_lstm = model_lstm.fit(X_train, y_train, epochs = 100, batch_size = 32, validation_data = (X_test, y_test))
# Out:
# Epoch 1/100
# 34/37 [==========================>...] - ETA: 0s - loss: 8.2098e-04
# 2024-05-20 09:33:20.198110: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-20 09:33:20.198736: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-20 09:33:20.199167: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-20 09:33:20.266042: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-20 09:33:20.266457: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-20 09:33:20.266842: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-20 09:33:20.332259: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-20 09:33:20.332725: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-20 09:33:20.333130: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-20 09:33:20.399151: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 37/37 [==============================] - 1s 29ms/step - loss: 8.1469e-04 - val_loss: 0.0011
# Epoch 2/100
#  1/37 [..............................] - ETA: 0s - loss: 7.6664e-04
# 2024-05-20 09:33:20.399664: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-20 09:33:20.400222: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 37/37 [==============================] - 1s 17ms/step - loss: 8.0419e-04 - val_loss: 0.0010
# Epoch 3/100
# 37/37 [==============================] - 1s 17ms/step - loss: 7.9413e-04 - val_loss: 9.0101e-04
# Epoch 4/100
# 37/37 [==============================] - 1s 17ms/step - loss: 7.6455e-04 - val_loss: 9.9925e-04
# Epoch 5/100
# 37/37 [==============================] - 1s 17ms/step - loss: 7.8396e-04 - val_loss: 0.0010
# Epoch 6/100
# 37/37 [==============================] - 1s 17ms/step - loss: 7.8672e-04 - val_loss: 9.0931e-04
# Epoch 7/100
# 37/37 [==============================] - 1s 17ms/step - loss: 8.6199e-04 - val_loss: 0.0026
# Epoch 8/100
# 37/37 [==============================] - 1s 17ms/step - loss: 8.2476e-04 - val_loss: 0.0021
# Epoch 9/100
# 37/37 [==============================] - 1s 17ms/step - loss: 8.2233e-04 - val_loss: 0.0019
# Epoch 10/100
# 37/37 [==============================] - 1s 17ms/step - loss: 8.7374e-04 - val_loss: 0.0015
# Epoch 11/100
# 37/37 [==============================] - 1s 17ms/step - loss: 7.2632e-04 - val_loss: 7.5466e-04
# Epoch 12/100
# 37/37 [==============================] - 1s 17ms/step - loss: 7.3798e-04 - val_loss: 7.3714e-04
# Epoch 13/100
# 37/37 [==============================] - 1s 17ms/step - loss: 7.6304e-04 - val_loss: 0.0011
# Epoch 14/100
# 37/37 [==============================] - 1s 17ms/step - loss: 7.9967e-04 - val_loss: 7.4199e-04
# Epoch 15/100
# 37/37 [==============================] - 1s 18ms/step - loss: 6.7224e-04 - val_loss: 0.0011
# Epoch 16/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.6843e-04 - val_loss: 7.3815e-04
# Epoch 17/100
# 37/37 [==============================] - 1s 17ms/step - loss: 7.0271e-04 - val_loss: 7.1879e-04
# Epoch 18/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.8159e-04 - val_loss: 7.9226e-04
# Epoch 19/100
# 37/37 [==============================] - 1s 17ms/step - loss: 7.2317e-04 - val_loss: 0.0021
# Epoch 20/100
# 37/37 [==============================] - 1s 17ms/step - loss: 7.5105e-04 - val_loss: 0.0010
# Epoch 21/100
# 37/37 [==============================] - 1s 17ms/step - loss: 7.1064e-04 - val_loss: 7.7329e-04
# Epoch 22/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.6659e-04 - val_loss: 0.0025
# Epoch 23/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.8362e-04 - val_loss: 0.0014
# Epoch 24/100
# 37/37 [==============================] - 1s 17ms/step - loss: 7.7460e-04 - val_loss: 6.9731e-04
# Epoch 25/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.6383e-04 - val_loss: 7.8672e-04
# Epoch 26/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.3231e-04 - val_loss: 0.0018
# Epoch 27/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.5210e-04 - val_loss: 7.1201e-04
# Epoch 28/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.4745e-04 - val_loss: 8.1767e-04
# Epoch 29/100
# 37/37 [==============================] - 1s 17ms/step - loss: 7.2024e-04 - val_loss: 0.0030
# Epoch 30/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.2790e-04 - val_loss: 6.9117e-04
# Epoch 31/100
# 37/37 [==============================] - 1s 17ms/step - loss: 7.4709e-04 - val_loss: 7.1699e-04
# Epoch 32/100
# 37/37 [==============================] - 1s 17ms/step - loss: 7.3274e-04 - val_loss: 6.7635e-04
# Epoch 33/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.4564e-04 - val_loss: 9.1805e-04
# Epoch 34/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.4583e-04 - val_loss: 0.0012
# Epoch 35/100
# 37/37 [==============================] - 1s 18ms/step - loss: 7.0579e-04 - val_loss: 6.8223e-04
# Epoch 36/100
# 37/37 [==============================] - 1s 17ms/step - loss: 7.0028e-04 - val_loss: 8.0249e-04
# Epoch 37/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.6752e-04 - val_loss: 0.0012
# Epoch 38/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.4733e-04 - val_loss: 0.0011
# Epoch 39/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.1650e-04 - val_loss: 0.0011
# Epoch 40/100
# 37/37 [==============================] - 1s 18ms/step - loss: 6.6338e-04 - val_loss: 0.0021
# Epoch 41/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.4706e-04 - val_loss: 0.0012
# Epoch 42/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.4862e-04 - val_loss: 9.6377e-04
# Epoch 43/100
# 37/37 [==============================] - 1s 19ms/step - loss: 6.4899e-04 - val_loss: 6.5763e-04
# Epoch 44/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.8856e-04 - val_loss: 0.0023
# Epoch 45/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.9195e-04 - val_loss: 0.0031
# Epoch 46/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.6724e-04 - val_loss: 0.0022
# Epoch 47/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.5733e-04 - val_loss: 0.0019
# Epoch 48/100
# 37/37 [==============================] - 1s 17ms/step - loss: 7.4809e-04 - val_loss: 0.0012
# Epoch 49/100
# 37/37 [==============================] - 1s 17ms/step - loss: 7.4144e-04 - val_loss: 9.7944e-04
# Epoch 50/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.9481e-04 - val_loss: 0.0012
# Epoch 51/100
# 37/37 [==============================] - 1s 17ms/step - loss: 5.4898e-04 - val_loss: 0.0012
# Epoch 52/100
# 37/37 [==============================] - 1s 17ms/step - loss: 5.5719e-04 - val_loss: 0.0033
# Epoch 53/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.5109e-04 - val_loss: 0.0020
# Epoch 54/100
# 37/37 [==============================] - 1s 17ms/step - loss: 5.8108e-04 - val_loss: 6.9474e-04
# Epoch 55/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.5802e-04 - val_loss: 6.5442e-04
# Epoch 56/100
# 37/37 [==============================] - 1s 18ms/step - loss: 6.2652e-04 - val_loss: 0.0047
# Epoch 57/100
# 37/37 [==============================] - 1s 18ms/step - loss: 6.9672e-04 - val_loss: 0.0017
# Epoch 58/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.1868e-04 - val_loss: 0.0012
# Epoch 59/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.0015e-04 - val_loss: 0.0011
# Epoch 60/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.9560e-04 - val_loss: 0.0033
# Epoch 61/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.7201e-04 - val_loss: 6.4201e-04
# Epoch 62/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.0397e-04 - val_loss: 0.0012
# Epoch 63/100
# 37/37 [==============================] - 1s 17ms/step - loss: 7.6337e-04 - val_loss: 6.6563e-04
# Epoch 64/100
# 37/37 [==============================] - 1s 19ms/step - loss: 6.1795e-04 - val_loss: 0.0017
# Epoch 65/100
# 37/37 [==============================] - 1s 18ms/step - loss: 6.9347e-04 - val_loss: 0.0028
# Epoch 66/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.6231e-04 - val_loss: 7.2142e-04
# Epoch 67/100
# 37/37 [==============================] - 1s 18ms/step - loss: 6.1339e-04 - val_loss: 0.0021
# Epoch 68/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.2191e-04 - val_loss: 8.5853e-04
# Epoch 69/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.2271e-04 - val_loss: 7.8787e-04
# Epoch 70/100
# 37/37 [==============================] - 1s 17ms/step - loss: 5.8606e-04 - val_loss: 0.0013
# Epoch 71/100
# 37/37 [==============================] - 1s 17ms/step - loss: 5.9223e-04 - val_loss: 8.6640e-04
# Epoch 72/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.3647e-04 - val_loss: 7.0670e-04
# Epoch 73/100
# 37/37 [==============================] - 1s 18ms/step - loss: 6.3844e-04 - val_loss: 0.0012
# Epoch 74/100
# 37/37 [==============================] - 1s 18ms/step - loss: 5.9364e-04 - val_loss: 0.0015
# Epoch 75/100
# 37/37 [==============================] - 1s 19ms/step - loss: 6.3334e-04 - val_loss: 0.0014
# Epoch 76/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.2152e-04 - val_loss: 0.0021
# Epoch 77/100
# 37/37 [==============================] - 1s 17ms/step - loss: 7.6543e-04 - val_loss: 0.0017
# Epoch 78/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.0694e-04 - val_loss: 0.0018
# Epoch 79/100
# 37/37 [==============================] - 1s 17ms/step - loss: 5.9913e-04 - val_loss: 9.6325e-04
# Epoch 80/100
# 37/37 [==============================] - 1s 17ms/step - loss: 5.3750e-04 - val_loss: 6.4752e-04
# Epoch 81/100
# 37/37 [==============================] - 1s 17ms/step - loss: 5.7779e-04 - val_loss: 9.2756e-04
# Epoch 82/100
# 37/37 [==============================] - 1s 20ms/step - loss: 5.9063e-04 - val_loss: 6.5984e-04
# Epoch 83/100
# 37/37 [==============================] - 1s 17ms/step - loss: 5.8151e-04 - val_loss: 7.0948e-04
# Epoch 84/100
# 37/37 [==============================] - 1s 17ms/step - loss: 5.9150e-04 - val_loss: 0.0013
# Epoch 85/100
# 37/37 [==============================] - 1s 17ms/step - loss: 5.6533e-04 - val_loss: 0.0011
# Epoch 86/100
# 37/37 [==============================] - 1s 21ms/step - loss: 5.7357e-04 - val_loss: 0.0014
# Epoch 87/100
# 37/37 [==============================] - 1s 19ms/step - loss: 6.3911e-04 - val_loss: 7.1274e-04
# Epoch 88/100
# 37/37 [==============================] - 1s 18ms/step - loss: 6.4049e-04 - val_loss: 0.0011
# Epoch 89/100
# 37/37 [==============================] - 1s 18ms/step - loss: 6.5452e-04 - val_loss: 0.0015
# Epoch 90/100
# 37/37 [==============================] - 1s 19ms/step - loss: 5.6024e-04 - val_loss: 0.0013
# Epoch 91/100
# 37/37 [==============================] - 1s 18ms/step - loss: 6.5767e-04 - val_loss: 0.0016
# Epoch 92/100
# 37/37 [==============================] - 1s 19ms/step - loss: 6.1134e-04 - val_loss: 0.0020
# Epoch 93/100
# 37/37 [==============================] - 1s 18ms/step - loss: 6.1286e-04 - val_loss: 8.1631e-04
# Epoch 94/100
# 37/37 [==============================] - 1s 18ms/step - loss: 6.2714e-04 - val_loss: 0.0054
# Epoch 95/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.8150e-04 - val_loss: 0.0016
# Epoch 96/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.2214e-04 - val_loss: 6.7338e-04
# Epoch 97/100
# 37/37 [==============================] - 1s 17ms/step - loss: 5.9076e-04 - val_loss: 9.9539e-04
# Epoch 98/100
# 37/37 [==============================] - 1s 20ms/step - loss: 6.5105e-04 - val_loss: 9.1689e-04
# Epoch 99/100
# 37/37 [==============================] - 1s 19ms/step - loss: 5.4962e-04 - val_loss: 9.8867e-04
# Epoch 100/100
# 37/37 [==============================] - 1s 18ms/step - loss: 6.1471e-04 - val_loss: 6.5136e-04

# %%
def plot_training_error(history):
    """
    Function to plot training and validation error over epochs.
    
    Parameters:
    - history: Keras history object containing training history
    """
    plt.plot(history.history['loss'], label='Train')
    plt.plot(history.history['val_loss'], label='Validation')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Training and Validation Error')
    plt.legend()
    plt.show()

# %%
plot_training_error(history_lstm)

# %%
# Prepare data for future prediction
def prepare_future_data(data, prediction_days):
    X_future = data[-prediction_days:].reshape(1, -1, 1)
    return X_future

# Predict future prices
def predict_future_prices(model, data, future_days):
    predictions = []
    current_batch = data[-future_days:].reshape(1, future_days, 1)

    for _ in range(future_days):
        current_pred = model.predict(current_batch)[0]
        predictions.append(current_pred)
        current_batch = np.append(current_batch[:, 1:, :], [[current_pred]], axis=1)
    
    return np.array(predictions).reshape(-1, 1)

# Inverse transform the predictions
def inverse_transform_predictions(scaler, predictions):
    return scaler.inverse_transform(predictions)

# %%
# Number of days to predict into the future
future_days = 30

# Prepare data for future prediction
X_future = prepare_future_data(df_scaled, future_days)

# Predict future prices
future_predictions = predict_future_prices(model_lstm, df_scaled, future_days)

# Inverse transform the predictions
future_predictions_inverse = inverse_transform_predictions(df_scaler, future_predictions)
# Out:
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step

# %%
# Plot the future predictions
def plot_future_predictions(ticker, future_pred):
    plt.figure(figsize=(10, 6))
    plt.plot(future_pred, color='red', label='Future Predictions')
    plt.title(f'Future Predicted Values for {TICK}')
    plt.xlabel('Days')
    plt.ylabel('Price')
    plt.legend()
    plt.show()

# %%
# Usage example for plotting predictions for specified tickers
plot_future_predictions(TICK, future_predictions_inverse)
