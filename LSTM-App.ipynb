# %%
import numpy as np 
import pandas as pd 
from sklearn import preprocessing
import matplotlib.pyplot as plt 
import seaborn as sns
import warnings
warnings.simplefilter(action='ignore')
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.preprocessing import MinMaxScaler
import datetime 
import yfinance as yf
from keras.models import Sequential
from keras.layers import LSTM, Dropout, Dense

# %% [markdown]
# ### Lets use the functions to model new stock symbol from user input

# %%
# Inputting the Stock symbol for prediction
TICK = input("Enter Stock symbol for prediction : ")
# Out:
# Enter Stock symbol for prediction : META

# %% [markdown]
# ### Fetching Historical Data from yahoo finance API for the tickers

# %%
# Fetch the data for last 5 years from yahoo
ticker = yf.Ticker(TICK)
ticker_data = ticker.history(period="60mo")
ticker_data['Company'] = TICK

# %%
ticker_data
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2019-05-20 00:00:00-04:00  181.687231  184.034731  181.177761  182.526337
# 2019-05-21 00:00:00-04:00  184.374380  185.503172  183.695093  184.624115
# 2019-05-22 00:00:00-04:00  184.534195  186.542074  183.415387  185.123581
# 2019-05-23 00:00:00-04:00  182.226659  183.705086  179.479574  180.678299
# 2019-05-24 00:00:00-04:00  182.136746  183.435371  180.638336  180.868088
# ...                               ...         ...         ...         ...
# 2024-05-13 00:00:00-04:00  472.750000  473.350006  462.850006  468.010010
# 2024-05-14 00:00:00-04:00  463.369995  472.540009  460.079987  471.850006
# 2024-05-15 00:00:00-04:00  474.980011  482.500000  471.200012  481.540009
# 2024-05-16 00:00:00-04:00  475.000000  477.690002  472.750000  473.230011
# 2024-05-17 00:00:00-04:00  470.829987  472.799988  468.420013  471.910004
#
#                              Volume  Dividends  Stock Splits Company
# Date
# 2019-05-20 00:00:00-04:00  10352000        0.0           0.0    META
# 2019-05-21 00:00:00-04:00   7502800        0.0           0.0    META
# 2019-05-22 00:00:00-04:00   9213800        0.0           0.0    META
# 2019-05-23 00:00:00-04:00  12768800        0.0           0.0    META
# 2019-05-24 00:00:00-04:00   8807700        0.0           0.0    META
# ...                             ...        ...           ...     ...
# 2024-05-13 00:00:00-04:00  14668800        0.0           0.0    META
# 2024-05-14 00:00:00-04:00  10478600        0.0           0.0    META
# 2024-05-15 00:00:00-04:00  13100500        0.0           0.0    META
# 2024-05-16 00:00:00-04:00  16608200        0.0           0.0    META
# 2024-05-17 00:00:00-04:00   9979600        0.0           0.0    META
#
# [1259 rows x 8 columns]

# %% [markdown]
# ### Visualize the stock portfolio performance of holding for last 5 years

# %%
# Visualize the stock portfolio performance of holding
fig, visual_plot = plt.subplots(figsize=(15,8))
visual_plot = sns.lineplot(data =ticker_data, x = ticker_data.index, y= ticker_data["Close"], hue = ticker_data["Company"])
visual_plot.set_title("Stock Prices of {}" .format(TICK))
visual_plot.set_xlabel('Last 5 Years', fontsize=16)
visual_plot.set_ylabel('Closing Price (USD)' , fontsize=16)
# Out:
# Text(0, 0.5, 'Closing Price (USD)')

# %% [markdown]
# ### Defining functions Model using LSTM calculate errors and predict stock price for next 30 days

# %%
# Define the function to retain only 'Close' prices
def close_prices_only(data):
    return data[['Close']]

# %%
## Function for scaling the data for LSTM

def min_max_scale(data):
    # Initialize MinMaxScaler
    scaler = MinMaxScaler(feature_range=(0, 1))
    
    # Fit and transform the data using the scaler
    scaled_data = scaler.fit_transform(data.values)
    
    return scaler, scaled_data

# %%
def split_and_reshape_data(dataframe, pred_days):
    # Define the number of days to predict
    prediction_days = pred_days
    
    # Calculate the sizes of the training and testing sets
    train_size = int(np.ceil(len(dataframe) * 0.95))
    test_size = len(dataframe) - train_size
    
    # Split the data into training and testing sets
    train_data = dataframe[0: int(train_size), :]
    test_data = dataframe[train_size - prediction_days:, :]
    
    # Initialize lists to store features and target values for training and testing
    X_train, y_train, X_test, y_test = [], [], [], []
    
    # Generate sequences of features and target values for training set
    for i in range(prediction_days, len(train_data)):
        X_train.append(train_data[i - prediction_days: i, 0])
        y_train.append(train_data[i, 0])
        
    # Generate sequences of features and target values for testing set
    for i in range(prediction_days, len(test_data)):
        X_test.append(test_data[i - prediction_days: i, 0])
        y_test.append(test_data[i, 0])
        
    # Convert lists to numpy arrays
    X_train, y_train, X_test, y_test = np.array(X_train), np.array(y_train), np.array(X_test), np.array(y_test)
    
    # Reshape the feature sets for LSTM input
    X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
    X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
    
    # Return the prepared data
    return X_train, y_train, X_test, y_test

# %%
def lstm_model(X_train, y_train, epochs=100, batch_size=32):
    """
    Function to build and train an LSTM model for stock price prediction.
    
    Parameters:
    - X_train: numpy array, training features
    - y_train: numpy array, training labels
    - epochs: int, number of epochs for training (default: 100)
    - batch_size: int, batch size for training (default: 32)
    
    Returns:
    - model: trained Keras model
    """
    # Build LSTM model
    model = Sequential()
    model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
    model.add(Dropout(0.2))
    model.add(LSTM(units=50, return_sequences=True))
    model.add(Dropout(0.2))
    model.add(LSTM(units=50, return_sequences=True))
    model.add(Dropout(0.2))
    model.add(LSTM(units=50))
    model.add(Dropout(0.2))
    model.add(Dense(units=1))

    # Compile the model
    model.compile(optimizer='adam', loss='mean_squared_error')

    # Train the model
    model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, verbose=0)

    return model

# %%
def predictions_inverse_scaler(scaler, model, X_test, y_test):
    """
    Function to inverse scale predicted and true values back to original scale.
    
    Parameters:
    - scaler: sklearn MinMaxScaler object, used for scaling the data
    - model: trained Keras model
    - X_test: numpy array, test features
    - y_test: numpy array, true test labels
    
    Returns:
    - y_pred: numpy array, inverse scaled predicted values
    - y_test: numpy array, inverse scaled true values
    """
    # Predictions using the model
    y_pred = model.predict(X_test)
    
    # Inverse scaling of predicted values
    y_pred = scaler.inverse_transform(y_pred)
    
    # Inverse scaling of true values
    y_test = scaler.inverse_transform(y_test.reshape(-1, 1))
    
    return y_pred, y_test

# %%
def plot_predictions(y_pred, y_true, ticker_label):
    """
    Function to plot predicted values against true values with ticker label.
    
    Parameters:
    - y_pred: numpy array, predicted values
    - y_true: numpy array, true values
    - ticker_label: str, label for the ticker
    """
    plt.figure(figsize=(10, 6))
    plt.plot(y_true, label='True Values')
    plt.plot(y_pred, label='Predicted Values')
    plt.title(f'True vs Predicted Values for {ticker_label}')
    plt.xlabel('Time')
    plt.ylabel('Price')
    plt.legend()
    plt.show()

# %%
df_close = close_prices_only(ticker_data)

# %%
# Scaling close prices for stock ticker
df_scaler, df_scaled = min_max_scale(df_close)

# %%
# Split and reshape data for each stock ticker
X_train, y_train, X_test, y_test = split_and_reshape_data(df_scaled, 30)

# %%
# Build the LSTM model
model_lstm = lstm_model(X_train, y_train)
# Out:
# 2024-05-18 13:39:59.888811: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-18 13:39:59.889611: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-18 13:39:59.890042: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-18 13:39:59.943415: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-18 13:39:59.943800: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-18 13:39:59.944129: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-18 13:39:59.996623: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-18 13:39:59.996998: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-18 13:39:59.997347: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-18 13:40:00.050679: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-18 13:40:00.051083: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-18 13:40:00.051415: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-18 13:40:00.142483: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2024-05-18 13:40:00.216748: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-18 13:40:00.217308: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-18 13:40:00.217790: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-18 13:40:00.278997: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-18 13:40:00.279470: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-18 13:40:00.279895: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-18 13:40:00.340641: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-18 13:40:00.341134: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-18 13:40:00.341558: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-18 13:40:00.406708: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-18 13:40:00.407299: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-18 13:40:00.407783: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-18 13:40:00.791106: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-18 13:40:00.791599: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-18 13:40:00.792103: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-18 13:40:00.860158: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-18 13:40:00.860604: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-18 13:40:00.860995: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-18 13:40:00.920560: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-18 13:40:00.921016: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-18 13:40:00.921422: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-18 13:40:00.981338: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-18 13:40:00.981779: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-18 13:40:00.982174: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
model_lstm.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 30, 50)            10400
#
#  dropout (Dropout)           (None, 30, 50)            0
#
#  lstm_1 (LSTM)               (None, 30, 50)            20200
#
#  dropout_1 (Dropout)         (None, 30, 50)            0
#
#  lstm_2 (LSTM)               (None, 30, 50)            20200
#
#  dropout_2 (Dropout)         (None, 30, 50)            0
#
#  lstm_3 (LSTM)               (None, 50)                20200
#
#  dropout_3 (Dropout)         (None, 50)                0
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 71,051
# Trainable params: 71,051
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Make predictions and inverse scale for each stock ticker
y_pred, y_test_inv = predictions_inverse_scaler(df_scaler, model_lstm, X_test, y_test)
# Out:
# 2024-05-18 13:41:01.452065: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-18 13:41:01.452566: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-18 13:41:01.453166: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-18 13:41:01.515802: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-18 13:41:01.516266: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-18 13:41:01.516682: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-18 13:41:01.587641: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-18 13:41:01.588126: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-18 13:41:01.588542: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-18 13:41:01.651284: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-18 13:41:01.651742: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-18 13:41:01.652176: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2/2 [==============================] - 0s 6ms/step

# %%
plot_predictions(y_pred, y_test_inv, TICK)

# %%
history_lstm = model_lstm.fit(X_train, y_train, epochs = 100, batch_size = 32, validation_data = (X_test, y_test))
# Out:
# Epoch 1/100
# 34/37 [==========================>...] - ETA: 0s - loss: 7.2809e-04
# 2024-05-18 13:41:02.614581: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-18 13:41:02.615072: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-18 13:41:02.615566: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-18 13:41:02.682199: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-18 13:41:02.682685: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-18 13:41:02.683100: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-18 13:41:02.748920: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-05-18 13:41:02.749385: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-18 13:41:02.749824: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-05-18 13:41:02.815711: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 37/37 [==============================] - 1s 30ms/step - loss: 7.2358e-04 - val_loss: 7.1913e-04
# Epoch 2/100
# 2024-05-18 13:41:02.816234: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-05-18 13:41:02.816789: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 37/37 [==============================] - 1s 19ms/step - loss: 6.6840e-04 - val_loss: 0.0048
# Epoch 3/100
# 37/37 [==============================] - 1s 17ms/step - loss: 7.7957e-04 - val_loss: 0.0010
# Epoch 4/100
# 37/37 [==============================] - 1s 17ms/step - loss: 7.5071e-04 - val_loss: 8.5676e-04
# Epoch 5/100
# 37/37 [==============================] - 1s 17ms/step - loss: 7.2810e-04 - val_loss: 7.3368e-04
# Epoch 6/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.9153e-04 - val_loss: 0.0014
# Epoch 7/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.7079e-04 - val_loss: 9.6343e-04
# Epoch 8/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.4809e-04 - val_loss: 0.0013
# Epoch 9/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.8564e-04 - val_loss: 0.0016
# Epoch 10/100
# 37/37 [==============================] - 1s 18ms/step - loss: 7.1753e-04 - val_loss: 0.0015
# Epoch 11/100
# 37/37 [==============================] - 1s 18ms/step - loss: 6.8114e-04 - val_loss: 8.3295e-04
# Epoch 12/100
# 37/37 [==============================] - 1s 18ms/step - loss: 6.6038e-04 - val_loss: 7.0838e-04
# Epoch 13/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.5315e-04 - val_loss: 0.0018
# Epoch 14/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.5954e-04 - val_loss: 0.0010
# Epoch 15/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.3886e-04 - val_loss: 6.9351e-04
# Epoch 16/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.7734e-04 - val_loss: 0.0012
# Epoch 17/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.8569e-04 - val_loss: 0.0013
# Epoch 18/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.8621e-04 - val_loss: 0.0015
# Epoch 19/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.3028e-04 - val_loss: 7.5039e-04
# Epoch 20/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.2191e-04 - val_loss: 0.0016
# Epoch 21/100
# 37/37 [==============================] - 1s 17ms/step - loss: 7.4396e-04 - val_loss: 0.0015
# Epoch 22/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.0583e-04 - val_loss: 0.0013
# Epoch 23/100
# 37/37 [==============================] - 1s 18ms/step - loss: 7.0700e-04 - val_loss: 0.0010
# Epoch 24/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.8623e-04 - val_loss: 7.3583e-04
# Epoch 25/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.2363e-04 - val_loss: 8.4742e-04
# Epoch 26/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.1053e-04 - val_loss: 0.0011
# Epoch 27/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.3672e-04 - val_loss: 6.4388e-04
# Epoch 28/100
# 37/37 [==============================] - 1s 17ms/step - loss: 5.7554e-04 - val_loss: 6.6744e-04
# Epoch 29/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.0658e-04 - val_loss: 0.0012
# Epoch 30/100
# 37/37 [==============================] - 1s 17ms/step - loss: 7.6296e-04 - val_loss: 7.5128e-04
# Epoch 31/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.0391e-04 - val_loss: 8.8520e-04
# Epoch 32/100
# 37/37 [==============================] - 1s 17ms/step - loss: 5.7635e-04 - val_loss: 0.0022
# Epoch 33/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.3964e-04 - val_loss: 9.2419e-04
# Epoch 34/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.7641e-04 - val_loss: 0.0017
# Epoch 35/100
# 37/37 [==============================] - 1s 17ms/step - loss: 5.7843e-04 - val_loss: 6.8956e-04
# Epoch 36/100
# 37/37 [==============================] - 1s 17ms/step - loss: 5.6633e-04 - val_loss: 6.7412e-04
# Epoch 37/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.6127e-04 - val_loss: 7.6612e-04
# Epoch 38/100
# 37/37 [==============================] - 1s 17ms/step - loss: 5.5245e-04 - val_loss: 8.2781e-04
# Epoch 39/100
# 37/37 [==============================] - 1s 17ms/step - loss: 5.9233e-04 - val_loss: 8.8188e-04
# Epoch 40/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.3311e-04 - val_loss: 0.0027
# Epoch 41/100
# 37/37 [==============================] - 1s 17ms/step - loss: 7.0317e-04 - val_loss: 6.5207e-04
# Epoch 42/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.1078e-04 - val_loss: 0.0025
# Epoch 43/100
# 37/37 [==============================] - 1s 17ms/step - loss: 5.7948e-04 - val_loss: 6.6161e-04
# Epoch 44/100
# 37/37 [==============================] - 1s 17ms/step - loss: 5.8305e-04 - val_loss: 6.4150e-04
# Epoch 45/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.2347e-04 - val_loss: 7.8690e-04
# Epoch 46/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.8482e-04 - val_loss: 7.8796e-04
# Epoch 47/100
# 37/37 [==============================] - 1s 18ms/step - loss: 5.8192e-04 - val_loss: 0.0011
# Epoch 48/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.0641e-04 - val_loss: 0.0012
# Epoch 49/100
# 37/37 [==============================] - 1s 18ms/step - loss: 5.6548e-04 - val_loss: 0.0014
# Epoch 50/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.1375e-04 - val_loss: 6.9971e-04
# Epoch 51/100
# 37/37 [==============================] - 1s 17ms/step - loss: 5.0008e-04 - val_loss: 0.0014
# Epoch 52/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.2646e-04 - val_loss: 8.2500e-04
# Epoch 53/100
# 37/37 [==============================] - 1s 17ms/step - loss: 5.8903e-04 - val_loss: 0.0025
# Epoch 54/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.5753e-04 - val_loss: 9.4833e-04
# Epoch 55/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.1598e-04 - val_loss: 0.0016
# Epoch 56/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.6441e-04 - val_loss: 6.2401e-04
# Epoch 57/100
# 37/37 [==============================] - 1s 17ms/step - loss: 5.8874e-04 - val_loss: 7.2873e-04
# Epoch 58/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.0771e-04 - val_loss: 7.2116e-04
# Epoch 59/100
# 37/37 [==============================] - 1s 17ms/step - loss: 5.1404e-04 - val_loss: 0.0012
# Epoch 60/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.0818e-04 - val_loss: 0.0010
# Epoch 61/100
# 37/37 [==============================] - 1s 17ms/step - loss: 5.6475e-04 - val_loss: 6.3302e-04
# Epoch 62/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.0683e-04 - val_loss: 0.0018
# Epoch 63/100
# 37/37 [==============================] - 1s 18ms/step - loss: 5.3527e-04 - val_loss: 0.0010
# Epoch 64/100
# 37/37 [==============================] - 1s 17ms/step - loss: 5.7951e-04 - val_loss: 7.1012e-04
# Epoch 65/100
# 37/37 [==============================] - 1s 17ms/step - loss: 5.9650e-04 - val_loss: 6.7207e-04
# Epoch 66/100
# 37/37 [==============================] - 1s 17ms/step - loss: 5.7176e-04 - val_loss: 6.1901e-04
# Epoch 67/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.9773e-04 - val_loss: 7.5725e-04
# Epoch 68/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.3678e-04 - val_loss: 0.0014
# Epoch 69/100
# 37/37 [==============================] - 1s 17ms/step - loss: 5.9464e-04 - val_loss: 0.0012
# Epoch 70/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.1625e-04 - val_loss: 0.0010
# Epoch 71/100
# 37/37 [==============================] - 1s 17ms/step - loss: 5.7380e-04 - val_loss: 0.0011
# Epoch 72/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.0670e-04 - val_loss: 8.3407e-04
# Epoch 73/100
# 37/37 [==============================] - 1s 17ms/step - loss: 5.9537e-04 - val_loss: 0.0014
# Epoch 74/100
# 37/37 [==============================] - 1s 18ms/step - loss: 5.3581e-04 - val_loss: 7.4032e-04
# Epoch 75/100
# 37/37 [==============================] - 1s 17ms/step - loss: 5.2712e-04 - val_loss: 6.2889e-04
# Epoch 76/100
# 37/37 [==============================] - 1s 17ms/step - loss: 5.2951e-04 - val_loss: 6.5853e-04
# Epoch 77/100
# 37/37 [==============================] - 1s 17ms/step - loss: 5.3999e-04 - val_loss: 0.0011
# Epoch 78/100
# 37/37 [==============================] - 1s 17ms/step - loss: 5.2758e-04 - val_loss: 6.2371e-04
# Epoch 79/100
# 37/37 [==============================] - 1s 17ms/step - loss: 5.3883e-04 - val_loss: 0.0013
# Epoch 80/100
# 37/37 [==============================] - 1s 17ms/step - loss: 5.8701e-04 - val_loss: 0.0010
# Epoch 81/100
# 37/37 [==============================] - 1s 17ms/step - loss: 5.8304e-04 - val_loss: 0.0040
# Epoch 82/100
# 37/37 [==============================] - 1s 17ms/step - loss: 5.4572e-04 - val_loss: 6.9011e-04
# Epoch 83/100
# 37/37 [==============================] - 1s 17ms/step - loss: 5.3558e-04 - val_loss: 6.3354e-04
# Epoch 84/100
# 37/37 [==============================] - 1s 17ms/step - loss: 5.3876e-04 - val_loss: 8.6356e-04
# Epoch 85/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.1496e-04 - val_loss: 7.6931e-04
# Epoch 86/100
# 37/37 [==============================] - 1s 17ms/step - loss: 5.7646e-04 - val_loss: 6.5459e-04
# Epoch 87/100
# 37/37 [==============================] - 1s 17ms/step - loss: 5.5310e-04 - val_loss: 6.7758e-04
# Epoch 88/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.0957e-04 - val_loss: 0.0015
# Epoch 89/100
# 37/37 [==============================] - 1s 17ms/step - loss: 5.3051e-04 - val_loss: 0.0014
# Epoch 90/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.0269e-04 - val_loss: 7.9031e-04
# Epoch 91/100
# 37/37 [==============================] - 1s 17ms/step - loss: 5.1521e-04 - val_loss: 6.5657e-04
# Epoch 92/100
# 37/37 [==============================] - 1s 17ms/step - loss: 5.7939e-04 - val_loss: 7.3671e-04
# Epoch 93/100
# 37/37 [==============================] - 1s 18ms/step - loss: 6.7426e-04 - val_loss: 0.0026
# Epoch 94/100
# 37/37 [==============================] - 1s 17ms/step - loss: 5.8765e-04 - val_loss: 0.0021
# Epoch 95/100
# 37/37 [==============================] - 1s 17ms/step - loss: 5.6643e-04 - val_loss: 0.0013
# Epoch 96/100
# 37/37 [==============================] - 1s 17ms/step - loss: 5.3733e-04 - val_loss: 0.0018
# Epoch 97/100
# 37/37 [==============================] - 1s 17ms/step - loss: 6.9030e-04 - val_loss: 8.7417e-04
# Epoch 98/100
# 37/37 [==============================] - 1s 17ms/step - loss: 5.5514e-04 - val_loss: 6.5797e-04
# Epoch 99/100
# 37/37 [==============================] - 1s 17ms/step - loss: 5.8327e-04 - val_loss: 0.0013
# Epoch 100/100
# 37/37 [==============================] - 1s 18ms/step - loss: 5.6212e-04 - val_loss: 0.0012

# %%
def plot_training_error(history):
    """
    Function to plot training and validation error over epochs.
    
    Parameters:
    - history: Keras history object containing training history
    """
    plt.plot(history.history['loss'], label='Train')
    plt.plot(history.history['val_loss'], label='Validation')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Training and Validation Error')
    plt.legend()
    plt.show()

# %%
plot_training_error(history_lstm)

# %%
# Prepare data for future prediction
def prepare_future_data(data, prediction_days):
    X_future = data[-prediction_days:].reshape(1, -1, 1)
    return X_future

# Predict future prices
def predict_future_prices(model, data, future_days):
    predictions = []
    current_batch = data[-future_days:].reshape(1, future_days, 1)

    for _ in range(future_days):
        current_pred = model.predict(current_batch)[0]
        predictions.append(current_pred)
        current_batch = np.append(current_batch[:, 1:, :], [[current_pred]], axis=1)
    
    return np.array(predictions).reshape(-1, 1)

# Inverse transform the predictions
def inverse_transform_predictions(scaler, predictions):
    return scaler.inverse_transform(predictions)

# %%
# Number of days to predict into the future
future_days = 30

# Prepare data for future prediction
X_future = prepare_future_data(df_scaled, future_days)

# Predict future prices
future_predictions = predict_future_prices(model_lstm, df_scaled, future_days)

# Inverse transform the predictions
future_predictions_inverse = inverse_transform_predictions(df_scaler, future_predictions)
# Out:
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step

# %%
# Plot the future predictions
def plot_future_predictions(ticker, future_pred):
    plt.figure(figsize=(10, 6))
    plt.plot(future_pred, color='red', label='Future Predictions')
    plt.title(f'Future Predicted Values for {TICK}')
    plt.xlabel('Days')
    plt.ylabel('Price')
    plt.legend()
    plt.show()

# %%
# Usage example for plotting predictions for specified tickers
plot_future_predictions(TICK, future_predictions_inverse)
